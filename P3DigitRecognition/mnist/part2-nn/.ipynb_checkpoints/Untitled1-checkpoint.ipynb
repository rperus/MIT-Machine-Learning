# %%
# conda install pytorch torchvision -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pytorch-1.12.0             |py3.8_cuda11.3_cudnn8_0        1.19 GB  pytorch
#     torchvision-0.13.0         |       py38_cu113         7.4 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        1.20 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/win-64::cudatoolkit-11.3.1-h59b6b97_2
#   libuv              pkgs/main/win-64::libuv-1.40.0-he774522_0
#   pytorch            pytorch/win-64::pytorch-1.12.0-py3.8_cuda11.3_cudnn8_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchvision        pytorch/win-64::torchvision-0.13.0-py38_cu113
#
# The following packages will be UPDATED:
#
#   certifi                        2022.5.18.1-py38haa95532_0 --> 2022.6.15-py38haa95532_0
#   openssl                                 1.1.1o-h2bbff1b_0 --> 1.1.1q-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# torchvision-0.13.0   | 7.4 MB    |            |   0%
# torchvision-0.13.0   | 7.4 MB    |            |   0%
#
# Note: you may need to restart the kernel to use updated packages.torchvision-0.13.0   | 7.4 MB    | 2          |   2%
# torchvision-0.13.0   | 7.4 MB    | 7          |   7%
#
# torchvision-0.13.0   | 7.4 MB    | #8         |  19%
# torchvision-0.13.0   | 7.4 MB    | ##5        |  25%
# torchvision-0.13.0   | 7.4 MB    | ####3      |  44%
# torchvision-0.13.0   | 7.4 MB    | #####5     |  55%
# torchvision-0.13.0   | 7.4 MB    | ######7    |  67%
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\Anaconda3
# torchvision-0.13.0   | 7.4 MB    | ########1  |  81%
# torchvision-0.13.0   | 7.4 MB    | #########4 |  95%
# torchvision-0.13.0   | 7.4 MB    | ########## | 100%
#
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   0%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   |            |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   1%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 1          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   2%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 2          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   3%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 3          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   4%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 4          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   5%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 5          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   6%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 6          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   7%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 7          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   8%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 8          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |   9%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | 9          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  10%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #          |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  11%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #1         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  12%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #2         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%
# pytorch-1.12.0       | 1.19 GB   | #3         |  13%

# %%
import _pickle as cPickle, gzip
import numpy as np
from tqdm import tqdm
import torch
import torch.autograd as autograd
import torch.nn.functional as F
import torch.nn as nn
import sys
sys.path.append("..")
import utils
from utils import *
from train_utils import batchify_data, run_epoch, train_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22336/1780863683.py in <module>
#       2 import numpy as np
#       3 from tqdm import tqdm
# ----> 4 import torch
#       5 import torch.autograd as autograd
#       6 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %%
pip install torch
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\__main__.py", line 21, in <module>
#     from pip._internal.cli.main import main as _main
# ModuleNotFoundError: No module named 'pip._internal.cli.main'

# %%
pip install torchvision
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pip\__main__.py", line 21, in <module>
#     from pip._internal.cli.main import main as _main
# ModuleNotFoundError: No module named 'pip._internal.cli.main'
